# %% [markdown]
# # KNN,Linear Regression,Prophet,for Stock Price Prediction
# I developed this tool mainly to gain more experience in time series analysis and object-oriented programming. I will occasionally update this project by adding more fuctions. Please do not use it for making investment or trading decision.

# %%
from prodictors import Prodictors #import Prodictors

ticker = 'IWM'
test_ticker = Prodictors(ticker)

# %%
# Applying Linear Regression to predict the furture price movement.
test_ticker.linear_prediction()
# Out:
# Linear Regression Prediction |  Ticker: IWM | Linear Regression Confidence:  0.9630073670373566

# %%
# Applying KNN to predict the future price movement.
test_ticker.knn_prediction()
# Out:
# KNN Prediction |  Ticker: IWM |  KNN Confidence: 0.9538744553061664

# %%
#Applying Prophet to predict stock price for the upcoming n Days
test_ticker.prophet_predict(days = 365) # predict the next 365 days stock price

# %% [markdown]
# # Quadratic Regression
#
# "Generally speaking, it is unusual to use d greater than 3 or 4 because for large values of d, the polynomial curve can become overly flexible and can take on some very strange shapes."
# — Page 266, An Introduction to Statistical Learning with Applications in R, 2014.

# %%
#Predicting price for the next year by applying Quadratic regression, PolynomiaFeatures, degree = 2;
test_ticker.quad_regression2()
# Out:
# Quadratic Regression 2 Prediction |  Ticker IWM |  Quad_R2 Confidence: 0.9538744553061664

# %%
#Predicting price for the next year by applying Quadratic regression, PolynomiaFeatures, degree = 3; High degrees can cause overfitting,
test_ticker.quad_regression3()
# Out:
# Quadratic Regression 3 Prediction |  Ticker IWM |  Quad_R3 Confidence: 0.9538744553061664

# %%
#Applying Prophet to analyze stock trend
test_ticker.trend_analizer(days = 365)# Forcasting the future trend

# %%
# Applying Prophet to customize DAYs to predict stock price
test_ticker.prophet_prediction(days = 10) #
# Out:
#            Date  Prediction         Low        High
# 3000 2021-12-02  229.907545  216.650336  241.952671
# 3001 2021-12-03  230.021856  217.394568  242.643589
# 3002 2021-12-04  230.136167  217.562880  244.269197
# 3003 2021-12-05  230.250478  217.914656  244.174330
# 3004 2021-12-06  230.364789  216.528084  244.018332
# 3005 2021-12-07  230.479100  216.675151  244.385464
# 3006 2021-12-08  230.593411  217.676438  245.293583
# 3007 2021-12-09  230.707722  217.059762  243.476060
# 3008 2021-12-10  230.822033  217.218081  244.061657
# 3009 2021-12-11  230.936344  218.128751  244.934639
